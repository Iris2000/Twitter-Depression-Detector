# %%
# !pip install twint
# !pip install nest_asyncio
# Out:
# ...
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\lvlip\anaconda3\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\lvlip\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# !pip3 install --user --upgrade git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# ...
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to c:\users\lvlip\appdata\local\temp\pip-install-0ib6lu4b\twint_d215eace9aae4bfb821c2e8c7b2519e2
#   Resolved https://github.com/twintproject/twint.git to commit origin/master
#   Preparing metadata (setup.py): started
#   Running command git clone --filter=blob:none -q https://github.com/twintproject/twint.git 'C:\Users\lvlip\AppData\Local\Temp\pip-install-0ib6lu4b\twint_d215eace9aae4bfb821c2e8c7b2519e2'
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
#   WARNING: The script twint.exe is installed in 'C:\Users\lvlip\AppData\Roaming\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# ...

# %%
# import library
import twint 
import nest_asyncio 
nest_asyncio.apply()

# %%
#configuration
config = twint.Config()
config.Since = "2021-12-16 00:00:00"
config.Search = "the"
config.Limit = 3000
config.Store_csv = True
config.Output = "C://Users//lvlip//Documents//BCSI Sem 6//FYP 4202//CSV//depression_twint//NormalOri4.csv"
config.Lang = "en"
#running search
twint.run.Search(config)

# %%
username = ['toogay_tootired', '_youarentalone', 'Im_Shy_Guy', 'sharonhanch', 'melodyacoba', 'bibipolarpj1', 'drunkbutter', 
            'kaceyla73', 'lunarmeow', 'bo00mer', 'jbehmke22', 'coley042216',
            'ithinkimokaykay', 'depressivegay1', 'wirednweird', 'nkatekokaygee7', 'tristimania101',
            'butterflyst0ry', 'bpdan23', 'the26phoenix', 'sickantyred', 'sinister_shark', '8675309dk', 'buttaluv8', 'killer_angel69',
            'juzzolee', 'parissienna1', 'fashionkattz', 'kikicandance', 'nikkiesteele', '_samwhisper_', 'celebidawn1996', 
            'desi_rueda', 'caringholly21', 'cantoocan', 'depressedloner9', 'itsdiannafl', 'alexander841211', 'TMummyof2',
            'lastcry4help', 'bellabuenoss', 'unstablefish1']

# %%
#configuration
config = twint.Config()
config.Since = "2021-01-05 00:00:00"
# config.Search = "#bipolar"
config.Username = "Im_Shy_Guy"
config.Limit = 1000
config.Store_csv = True
config.Output = "C://Users//lvlip//Documents//BCSI Sem 6//FYP 4202//CSV//depression_twint//bipolar.csv"
config.Lang = "en"

# %%
#running search
twint.run.Search(config)
# Out:
# 1476905374179463168 2021-12-31 21:17:35 +0800 <DarshanSelvam> @UpdatesChennai Lost Hope with AAI, No Second Airport , No Satellite Terminal, No Proper Crowd Management, No Proper Restrooms, Falling glasses and Failing infra in current Chennai Airport, Although Chennai is in the list of world's fastest growing cities, AAI Not Interested in TN.
# 1476905373927755778 2021-12-31 21:17:35 +0800 <faisal27875> @indiacharts I am sorry I made a faux pas , ew with gann, it was the "high probability" part which confused me. But I do believe that one cannot afford to predict and should always prepare.
# 1476905373634379776 2021-12-31 21:17:35 +0800 <538liban> wanna inject myself in the family tree through maria
# 1476905373563080705 2021-12-31 21:17:35 +0800 <clakklaa> I would do this. The Healthiest embryo possible. From two daft pricks.
# ...
